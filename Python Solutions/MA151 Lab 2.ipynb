# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric)

# %% [markdown]
# ## 1a volume of ice cream in cone

# %%
L = 4
theta = 15*pi/180
r = L * sin(theta)
h = L * cos(theta)
Vol = 1/3*pi*r**2*h + 2/3*pi*r**3
print('The volume of ice cream is', Vol.evalf(),'cubic inches')
# Out:
# The volume of ice cream is 6.66050739607502 cubic inches

# %% [markdown]
# ## 1b slant height needed for one cup

# %%
L = symbols('L')
r = L * sin(theta)
h = L * cos(theta)
Vol = 1/3*pi*r**2*h + 2/3*pi*r**3
VolEqn = Vol - 14.5
soln = solve(VolEqn, L)
print('The slant height of the cone should be about', soln[0].evalf(), 'inches')
# Out:
# The slant height of the cone should be about 5.18418176872302 inches

# %% [markdown]
# ## 2a Plot the function

# %%
matplotlib notebook

# %%
x = symbols('x')
f = x + 1/(x**2-1)
plot(f, (x,-4,4), ylim=[-10,10])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 2b Analysis of vertical asymptotes

# %%
print('The vertical asymptotes are x = -1 and x = 1')
print('As x approaches -1 from the left, f(x) approaches oo')
print('As x approaches -1 from the right, f(x) approaches -oo')
print('As x approaches 1 from the left, f(x) approaches -oo')
print('As x approaches 1 from the right, f(x) approaches oo')
# Out:
# The vertical asymptotes are x = -1 and x = 1
# As x approaches -1 from the left, f(x) approaches oo
# As x approaches -1 from the right, f(x) approaches -oo
# As x approaches 1 from the left, f(x) approaches -oo
# As x approaches 1 from the right, f(x) approaches oo

# %% [markdown]
# ## 3a plots of circles

# %%
matplotlib notebook

# %%
t = symbols('t')
plot_parametric((7*cos(t),7*sin(t),(t,0,2*pi)),(3+5*cos(t),4+5*sin(t),(t,0,2*pi)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 3b intersections of circles

# %%
t,s = symbols('t s')
x1 = 7.0*cos(t)
x2 = 3.0 + 5*cos(s)
y1 = 7.0*sin(t)
y2 = 4.0 + 5*sin(s)
slns = solve([x1-x2,y1-y2],[t,s])
print('The t and s solutions are', slns)
print('The first intersection is (',x1.subs(t,slns[0][0]),',', y1.subs(t,slns[0][0]),')')
print('The second intersection is (',x1.subs(t,slns[0][1]),',', y1.subs(t,slns[0][1]),')')
# Out:
# The t and s solutions are [(0.131896387817469, -0.663502442366675), (1.72269404818576, 2.51809287836990)]
# The first intersection is ( 6.93919991998400 , 0.920600060012003 )
# The second intersection is ( 5.51487988797759 , -4.31115991598320 )
