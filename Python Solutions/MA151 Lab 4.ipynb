# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric)

# %% [markdown]
# ## 1a Tangent line at x=2

# %%
x = symbols('x')
f = 5 * x/(1+x**2)
df = diff(f,x)
mtan = df.subs(x,2)
yval = f.subs(x,2)
tanlineeqn = expand(mtan*(x-2)+yval) #expand makes the function look nicer
print('The equation of the tangent line is y =', tanlineeqn)
# Out:
# The equation of the tangent line is y = -3*x/5 + 16/5

# %% [markdown]
# ## 1b Graph of f and tangent line

# %%
matplotlib notebook

# %%
plot((f,(x,0,4)), (tanlineeqn,(x,0,4)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 2a Velocity after 1 second

# %%
t = symbols('t', positive = True)
s = 1+10*t-1.86*t**2
vel = diff(s,t)
v1 = vel.subs(t,1)
print('The velocity after 1 second is', v1, 'm/s')
# Out:
# The velocity after 1 second is 6.28000000000000 m/s

# %% [markdown]
# ## 2b when v=0 and corresponding height

# %%
vis0 = solve(vel,t)
smax = s.subs(t,vis0[0])
print('The velocity is 0 after', vis0[0], 'seconds')
print('Height at this time is', smax, 'meters')
# Out:
# The velocity is 0 after 2.68817204301075 seconds
# Height at this time is 14.4408602150538 meters

# %% [markdown]
# ## 2c velocity when hits the surface

# %%
hitsurf = solve(s,t)[0]
vhit = vel.subs(t,hitsurf)
print('The rock will hit the surface with a velocity of', vhit, 'm/s')
# Out:
# The rock will hit the surface with a velocity of -10.3653268158799 m/s

# %% [markdown]
# ## 3a plot of f

# %%
x = symbols('x', real=True)
f = x*exp(-abs(x))
plot(f,(x,-5,5))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 3b Equations of horizontal tangent lines

# %%
x_neg = x*exp(x)
x_pos = x*exp(-x)
x_neg_crit_pt = solve(diff(x_neg,x), x)
x_pos_crit_pt = solve(diff(x_pos,x), x)
print('The equations are y =', f.subs(x,x_neg_crit_pt[0]), 'and y =', f.subs(x,x_pos_crit_pt[0]))
# Out:
# The equations are y = -exp(-1) and y = exp(-1)

# %% [markdown]
# ## 4a first 16 derivatives

# %%
x = symbols('x')
f = x*sin(x)
derivs = [diff(f,(x,i)) for i in range(1,17)]
print('The first 16 derivatives are:', derivs)
# Out:
# The first 16 derivatives are: [x*cos(x) + sin(x), -x*sin(x) + 2*cos(x), -(x*cos(x) + 3*sin(x)), x*sin(x) - 4*cos(x), x*cos(x) + 5*sin(x), -x*sin(x) + 6*cos(x), -(x*cos(x) + 7*sin(x)), x*sin(x) - 8*cos(x), x*cos(x) + 9*sin(x), -x*sin(x) + 10*cos(x), -(x*cos(x) + 11*sin(x)), x*sin(x) - 12*cos(x), x*cos(x) + 13*sin(x), -x*sin(x) + 14*cos(x), -(x*cos(x) + 15*sin(x)), x*sin(x) - 16*cos(x)]

# %% [markdown]
# ## 4b formula for nth, (n+1)th, (n+2)th, (n+3)th derivative if n divisible by 4

# %%
print("f^(n)(x) = x*sin(x) - n*cos(x)")
print("f^(n+1)(x) = x*cos(x) + (n+1)*sin(x)")
print("f^(n)(x) = -x*sin(x) + (n+2)*cos(x)")
print("f^(n)(x) = -x*cos(x) - (n+3)*sin(x)")
# Out:
# f^(n)(x) = x*sin(x) - n*cos(x)
# f^(n+1)(x) = x*cos(x) + (n+1)*sin(x)
# f^(n)(x) = -x*sin(x) + (n+2)*cos(x)
# f^(n)(x) = -x*cos(x) - (n+3)*sin(x)
