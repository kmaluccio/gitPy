# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric)

# %% [markdown]
# ## 1a Values of r which solve differential equation

# %%
r, x = symbols('r x')
f = E**(r*x)
df = diff(f,x)
ddf = diff(f,x,2)
deq = ddf + 5*df + 6*f
r_soln = solve(deq,r)
print('The values of r are', r_soln)
# Out:
# The values of r are [-3, -2]

# %% [markdown]
# ## 1b Values of r which solve differential equation

# %%
deq2 = ddf + 6*df + 13*f
r_soln2 = solve(deq2, r)
print('The values of r are', r_soln2)
# Out:
# The values of r are [-3 - 2*I, -3 + 2*I]

# %% [markdown]
# ## 1c Compute left hand side with cosines and sines and conclusion

# %%
y = E**(-3*x)*(cos(2*x)+sin(2*x))
dy = diff(y,x)
ddy = diff(y,x,2)
eqn = ddy + 6*dy + 13*y
print('The left hand side yields', eqn.simplify(), 'which means y satisfies the differential equation')
print('The exponential e raised to a complex exponent yields sines and cosines')
# Out:
# The left hand side yields 0 which means y satisfies the differential equation
# The exponential e raised to a complex exponent yields sines and cosines

# %% [markdown]
# ## 2a Implicit Plot

# %%
matplotlib notebook

# %%
x, y = symbols('x y', real = True) #want real values here, not imaginary
F = (x**2+y**2)**2 - 4*(x**2-y**2) + 3
Fplot = plot_implicit(F, (x,-3,3), (y,-3,3))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 2b dy/dx

# %%
dydx = idiff(F,y,x)
print('The implicit derivative of y is', dydx)
# Out:
# The implicit derivative of y is x*(-x**2 - y**2 + 2)/(y*(x**2 + y**2 + 2))

# %% [markdown]
# ## 2c horizontal tangent lines

# %%
htanpts = solve([F,dydx],x,y,real=True)
print('There are horizontal tangents at', htanpts)
# Out:
# There are horizontal tangents at [(-sqrt(30)/4, -sqrt(2)/4), (-sqrt(30)/4, sqrt(2)/4), (sqrt(30)/4, -sqrt(2)/4), (sqrt(30)/4, sqrt(2)/4)]

# %% [markdown]
# ## 2d Tangent line equation at (sqrt(2), sqrt(sqrt(17)-4))

# %%
x1 = sqrt(2)
y1 = sqrt(sqrt(17)-4)
m = dydx.subs({x:x1,y:y1})
print(m)
tanline = m*(x-x1) + y1
print('The equation of the tangent line to the curve at the given point is y =', tanline)
# Out:
# -sqrt(34)*sqrt(-4 + sqrt(17))/17
# The equation of the tangent line to the curve at the given point is y = -sqrt(34)*sqrt(-4 + sqrt(17))*(x - sqrt(2))/17 + sqrt(-4 + sqrt(17))

# %% [markdown]
# ## 2e Plot equation with tangent line from part d

# %%
matplotlib notebook

# %%
tangentplot = plot(tanline, (x,-3,3), ylim=[-3,3], show=False)
Fplot.extend(tangentplot)
Fplot.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 3a (n+1)th derivative of x^n log(x)

# %%
x, n = symbols('x n')
derivs = [diff(x**n*log(x), x, n+1) for n in range(2,9)]
print('For n = 2..8, the (n+1)th derivative of x^n*ln(x) is', derivs)
# Out:
# For n = 2..8, the (n+1)th derivative of x^n*ln(x) is [2/x, 6/x, 24/x, 120/x, 720/x, 5040/x, 40320/x]

# %% [markdown]
# ## 3b Conclusion

# %%
print('In general, the (n+1)th derivative of x^n*ln(x) is n!/x')
# Out:
# In general, the (n+1)th derivative of x^n*ln(x) is n!/x

# %% [markdown]
# ## 4a logarithmic differentiation

# %%
# in part a we take the log of both sides by hand and solve this way
x = symbols('x', real=True, positive=True)
y = x**(sqrt(x))
lny = sqrt(x)*log(x)
dlny = diff(lny,x)
dydx = y*dlny
print(dydx)
# can also use expand log command
lny = expand_log(log(y), force=True)
print(lny)
dlny = diff(lny,x)
dydx = y*dlny
print('Using logarithmic differentiation, the derivative is', dydx)
# Out:
# x**(sqrt(x))*(log(x)/(2*sqrt(x)) + 1/sqrt(x))
# sqrt(x)*log(x)
# Using logarithmic differentiation, the derivative is x**(sqrt(x))*(log(x)/(2*sqrt(x)) + 1/sqrt(x))

# %% [markdown]
# ## 4b direct differentiation

# %%
print('The derivative of y directly is', diff(y,x))
# Out:
# The derivative of y directly is x**(sqrt(x))*(log(x)/(2*sqrt(x)) + 1/sqrt(x))
