# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric)

# %% [markdown]
# # 1a Equation of tangent line when t=pi/4

# %%
t = symbols('t')
x = cos(t)
y = sin(t)+3
x0 = x.subs(t,pi/4)
y0 = y.subs(t,pi/4)
dx = diff(x,t)
dy = diff(y,t)
dydx = dy/dx
m = dydx.subs(t,pi/4)
x = symbols('x')
tanline = m*(x-x0)+y0
print('The equation of the tangent line is y=', tanline, 'or approximately', tanline.evalf())
# Out:
# The equation of the tangent line is y= -x + sqrt(2) + 3 or approximately -x + 4.41421356237309

# %% [markdown]
# ## 1b points where tangent line is vertical

# %%
v_tan = solve(dx,t)
xt = cos(t)
print(v_tan)
print('The curve has vertical tangent lines at (', xt.subs(t,v_tan[0]),',',y.subs(t,v_tan[0]),') and at (', xt.subs(t,v_tan[1]), ',', y.subs(t,v_tan[1]),')')
# Out:
# [0, pi]
# The curve has vertical tangent lines at ( 1 , 3 ) and at ( -1 , 3 )

# %% [markdown]
# ## 1c Plot parametrized curve and all tangent lines

# %%
matplotlib notebook

# %%
plotcurve = plot_parametric(xt, y, (t,0,2*pi),xlim=[-4,4],ylim=[0,6], show=False)
plotv_tan1 = plot_parametric(1, t, (t,0,2*pi), show=False)
plotv_tan2 = plot_parametric(-1, t, (t,0,2*pi), show=False)
plottanpi = plot(tanline, (x,-4,4), ylim=[0,6], show=False)
plotcurve.extend(plotv_tan1)
plotcurve.extend(plotv_tan2)
plotcurve.extend(plottanpi)
plotcurve.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 2a Tangent lines at (3,0)

# %%
t, x = symbols('t x')
f = t**2
g = t**3 - 3*t
tsoln = solve([f-3,g],t)
print(tsoln)
df = diff(f,t)
dg = diff(g,t)
dydx = dg/df
m1 = dydx.subs(t,-sqrt(3))
m2 = dydx.subs(t,sqrt(3))
tanline1 = m1*(x-3)
tanline2 = m2*(x-3)
print('The equations of the tangent lines are y=', tanline1, 'and y=', tanline2)
# Out:
# [(-sqrt(3),), (sqrt(3),)]
# The equations of the tangent lines are y= -sqrt(3)*(x - 3) and y= sqrt(3)*(x - 3)

# %% [markdown]
# ## 2b Plot of parametrized curve and tangent lines

# %%
matplotlib notebook

# %%
pf = plot_parametric(f,g,(t,-2,2), show=False)
pf.extend(plot((-sqrt(3)*(x-3), (x,0,4)), (sqrt(3)*(x-3),(x,0,4)), show=False))
pf.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 3a find k and y0

# %%
k, y0 = symbols('k y0')
y = y0*E**(k*t)
eqn1 = y.subs(t,1) - 200
eqn2 = y.subs(t,Rational(3,2)) - 360
solns = solve([eqn1,eqn2], [k,y0])
print('k =', solns[0][0].evalf(), ' y0 =', solns[0][1].evalf())
# Out:
# k = 1.17557332980424  y0 = 61.7283950617284

# %% [markdown]
# ## 3b When population = 2000

# %%
y = solns[0][1]*E**(solns[0][0]*t)
tsoln = solve(y-2000,t)
print('Count reaches 2,000 after', tsoln[0],', or approximately', tsoln[0].evalf(),'hours')
# Out:
# Count reaches 2,000 after log((162/5)**(1/log(81/25))) , or approximately 2.95869116338109 hours

# %% [markdown]
# ## 3c find k and population 1 hour before "initial"

# %%
newy = 200*E**(k*t)
newk = solve(newy.subs(t,0.5)-360,k)
y = 200*E**(newk[0]*t)
yatneg1 = y.subs(t,-1)
print('k = ', newk[0])
print('Count at t=-1 is', yatneg1, 'bacteria, which is the same as the original initial amount')
# Out:
# k =  1.17557332980424
# Count at t=-1 is 61.7283950617284 bacteria, which is the same as the original initial amount

# %% [markdown]
# ## 4a rate of change in f with respect to each variable

# %%
L,T,p = symbols('L T p')
f = 1/(2*L)*sqrt(T/p)
dfdL = diff(f,L)
dfdT = diff(f,T)
dfdp = diff(f,p)
print('The derivative of f with respect to:')
print('L is', dfdL)
print('T is', dfdT)
print('rho is', dfdp)
# Out:
# The derivative of f with respect to:
# L is -sqrt(T/p)/(2*L**2)
# T is sqrt(T/p)/(4*L*T)
# rho is -sqrt(T/p)/(4*L*p)

# %% [markdown]
# ## 4b interpret what happens to the pitch

# %%
print('As the string length decreases, the frequency increases, creating a higher pitch.')
print('As the tension increases, the frequencey increases, creating a higher pitch.')
print('As the density increases, the frequency decreases, creating a lower pitch.')
# Out:
# As the string length decreases, the frequency increases, creating a higher pitch.
# As the tension increases, the frequencey increases, creating a higher pitch.
# As the density increases, the frequency decreases, creating a lower pitch.

# %% [markdown]
# ## 4c Plot rho vs T

# %%
matplotlib notebook

# %%
F = symbols('F')
rho = solve(F-f, p)[0]
plot(rho.subs({F:440, L:0.30}), (T,0,100))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 4d tuning tension when rho=.00078

# %%
rhoval = rho.subs({F:440,L:0.30})
Ttune = solve(rhoval - 0.00078, T)
print('The required tension is', Ttune[0], 'N')
# Out:
# The required tension is 54.3628800000000 N
