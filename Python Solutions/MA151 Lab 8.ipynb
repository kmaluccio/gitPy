# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric)

# %% [markdown]
# ## 1a find and simplify the derivative of f-g

# %%
x = symbols('x', positive=True)
f = 2*asin(x)
g = acos(1-2*x**2)
dfminusg = diff(f-g,x)
print('The derivative of f(x)-g(x) =', dfminusg.simplify())
# Out:
# The derivative of f(x)-g(x) = 0

# %% [markdown]
# ## 1b, 1c Implication of f-g and specific answer

# %%
print('This tells us that f(x)-g(x) is a constant')
print(f.subs(x,0)-g.subs(x,0),'is the value of the constant, so f(x)=g(x)')
# Out:
# This tells us that f(x)-g(x) is a constant
# 0 is the value of the constant, so f(x)=g(x)

# %% [markdown]
# ## 2a critical values of g

# %%
x = symbols('x')
g = -5*x**4 - 20*x**3 + 18
dg = diff(g,x)
critvals = solve(dg,x)
print('The critical values of the function g(x) are', critvals)
# Out:
# The critical values of the function g(x) are [-3, 0]

# %% [markdown]
# ## 2b intervals where g is increasing/decreasing

# %%
matplotlib notebook

# %%
plot(dg,(x,-4,1)) #checked domain here and this works nicely
print('From the graph, g is increasing on (-oo,-3)')
print('and decreasing on (-3,0) U (0,oo)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# From the graph, g is increasing on (-oo,-3)
# and decreasing on (-3,0) U (0,oo)

# %% [markdown]
# ## 2c where g'' = 0

# %%
ddg = diff(g,x,2)
ivalues = solve(ddg,x)
print(ivalues)
# Out:
# [-2, 0]

# %% [markdown]
# ## 2d intervals of concavity of g

# %%
matplotlib notebook

# %%
plot(ddg,(x,-3,1))
print('From the graph, g is concave up on (-2,0)')
print( 'and concave down on (-oo,-2) U (0,oo)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# From the graph, g is concave up on (-2,0)
# and concave down on (-oo,-2) U (0,oo)

# %% [markdown]
# ## 2e plot to graphically confirm answers to parts b and d

# %%
matplotlib notebook

# %%
plot(g,(x,-4,1))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 3a plot of f and number of extrema and inflection points based on graph

# %%
matplotlib notebook

# %%
x = symbols('x',real=True)
f = (x**2*(x+1)**3)/((x-2)**2*(x-4)**4)
plot(f,(x,-10,10))
print('There appear to be no local extrema or inflection points')
# Out:
# <img src="data:image/png;base64,..." width="640">
# There appear to be no local extrema or inflection points

# %% [markdown]
# ## 3b f' and critical values

# %%
df = diff(f,x)
print('The derivative of f is', df.simplify())
cvals = solve(df,x)
print(cvals)
cvalsdec = [i.evalf() for i in cvals]
print('The critical values are', cvalsdec)
# Out:
# The derivative of f is x*(x + 1)**2*(-2*x*(x - 4)*(x + 1) - 4*x*(x - 2)*(x + 1) + (x - 4)*(x - 2)*(5*x + 2))/((x - 4)**5*(x - 2)**3)
# [-1, 0, -6 - 152/((-1/2 - sqrt(3)*I/2)*(9180 + 12*sqrt(73239)*I)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(9180 + 12*sqrt(73239)*I)**(1/3)/3, -6 - (-1/2 + sqrt(3)*I/2)*(9180 + 12*sqrt(73239)*I)**(1/3)/3 - 152/((-1/2 + sqrt(3)*I/2)*(9180 + 12*sqrt(73239)*I)**(1/3)), -6 - (9180 + 12*sqrt(73239)*I)**(1/3)/3 - 152/(9180 + 12*sqrt(73239)*I)**(1/3)]
# The critical values are [-1.00000000000000, 0, -0.321983253601638 + 0.e-22*I, 2.46674654943711 - 0.e-22*I, -20.1447632958355 + 0.e-20*I]

# %% [markdown]
# ## 3c intervals of increase or decrease (attempted both)

# %%
matplotlib notebook

# %%
plot(df,(x,-21,5),ylim=[-1,1])
testvalues = [-21, -5, -0,5, -0.2, 1, 2.2, 3, 5]
dfsign = [df.subs({x:i}) for i in testvalues]
print('The y values of the first derivative at each test point are', dfsign)
print('So, f is increasing on (-20.14,-1) U (-1,-0.32) U (0,2) U (2.47,4)')
print('and decreasing on (-oo,-20.14) U (-0.32,0) U (2,2.47) U (4,oo)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# The y values of the first derivative at each test point are [-27888/950546875, 42320/20253807, 0, -2260, -5.96769084340646e-5, 164/243, -2240.20051143965, 1968, -2260]
# So, f is increasing on (-20.14,-1) U (-1,-0.32) U (0,2) U (2.47,4)
# and decreasing on (-oo,-20.14) U (-0.32,0) U (2,2.47) U (4,oo)

# %% [markdown]
# ## 3d intervals of concavity

# %%
ddf = diff(df, x)
print('The second derivative is', ddf.factor())
c2values = solve(ddf,x)
c2values_float = [i.evalf() for i in c2values]
print('The inflection points are', c2values_float)
testvals = [-40,-10,-2,-0.7,-0.3,0,3,5]
ddfsign = [ddf.subs({x:i}) for i in testvals]
print('The y values of the second derivative at each test point are', ddfsign)
print('So f is concave up on (-35.31, -4.98) U (-1,-0.54) U (-0.11,2) U (2,4) U (4,oo)')
print('and concave down on (-oo,-35.31) U (-4.98,-1) U (-0.54,-0.11)')
# Out:
# The second derivative is 2*(x + 1)*(x**6 + 36*x**5 + 6*x**4 - 628*x**3 + 684*x**2 + 672*x + 64)/((x - 4)**6*(x - 2)**4)
# The inflection points are [-1.00000000000000, -35.3113256040630, -4.97777332154410, -0.542718018300141, -0.108385637343953]
# The y values of the second derivative at each test point are [-3507439/2177801196032, 12849/60236288, -343/373248, 0.000146290982090729, -0.000467903382171413, 1/512, 9944, 10948]
# So f is concave up on (-35.31, -4.98) U (-1,-0.54) U (-0.11,2) U (2,4) U (4,oo)
# and concave down on (-oo,-35.31) U (-4.98,-1) U (-0.54,-0.11)

# %% [markdown]
# ## 3e actual number of local extrema and inflection points

# %%
print('There are 4 local extrema and 5 inflection points')
# Out:
# There are 4 local extrema and 5 inflection points

# %% [markdown]
# ## 4a Define f and g for natural log of y

# %%
x = symbols('x',real=True)
y = (1-6*x)**(1/x)
# take log of both sides and write f and g
f = ln(1-6*x)
g = x
print('ln(y)=f(x)/g(x), where f=',f,'and g=',g)
# Out:
# ln(y)=f(x)/g(x), where f= log(-6*x + 1) and g= x

# %% [markdown]
# ## 4b limits of f and g as x approaches 0

# %%
F = limit(f,x,0)
G = limit(g,x,0)
print('f(x) approaches', F, 'and g(x) approaches',G,'as x approaches 0')
# Out:
# f(x) approaches 0 and g(x) approaches 0 as x approaches 0

# %% [markdown]
# ## 4c Apply L'Hospital's Rule (if applicable)

# %%
print("Since conditions for l'hospitals rule are met, we can apply it here")
df = diff(f,x)
dg = diff(g,x)
newF = limit(df,x,0)
newG = limit(dg,x,0)
print("f'(x) approaches", newF,"and g'(x) approaches", newG,'as x approaches 0')
print('Therefore, ln(y) approaches',newF/newG,'and y therefore approaches', exp(newF/newG))
# Out:
# Since conditions for l'hospitals rule are met, we can apply it here
# f'(x) approaches -6 and g'(x) approaches 1 as x approaches 0
# Therefore, ln(y) approaches -6 and y therefore approaches exp(-6)

# %% [markdown]
# ## 4d limit directly in Python

# %%
L = limit(y,x,0)
print('The limit from Python of y is', L)
# Out:
# The limit from Python of y is exp(-6)
